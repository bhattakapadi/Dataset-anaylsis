# %%
import os
import pandas as pd

# %%
folder_dir = "/home/manish/Documents/dataset"
tempDataset="/home/manish/Documents/dataset/part-00039-5d6701c4-b238-4c0a-84e4-fe8e9daea963-c000.snappy.parquet" 
folder_to_evaluate="/home/manish/Documents/ceos"

# %%
for dataset in os.listdir(folder_dir):
    print(dataset)
# Out:
# part-00039-5d6701c4-b238-4c0a-84e4-fe8e9daea963-c000.snappy.parquet
# part-00001-5d6701c4-b238-4c0a-84e4-fe8e9daea963-c000.snappy.parquet
# part-00100-5d6701c4-b238-4c0a-84e4-fe8e9daea963-c000.snappy.parquet
# part-00000-5d6701c4-b238-4c0a-84e4-fe8e9daea963-c000.snappy.parquet
# part-00127-5d6701c4-b238-4c0a-84e4-fe8e9daea963-c000.snappy.parquet
# part-00084-5d6701c4-b238-4c0a-84e4-fe8e9daea963-c000.snappy.parquet

# %%
for dataset in os.listdir(folder_dir):
    datasetName = folder_dir+"/"+dataset
    data = pd.read_parquet(datasetName, engine='pyarrow')
    
    print(dataset)
# Out:
# part-00039-5d6701c4-b238-4c0a-84e4-fe8e9daea963-c000.snappy.parquet
# part-00001-5d6701c4-b238-4c0a-84e4-fe8e9daea963-c000.snappy.parquet
# part-00100-5d6701c4-b238-4c0a-84e4-fe8e9daea963-c000.snappy.parquet
# part-00000-5d6701c4-b238-4c0a-84e4-fe8e9daea963-c000.snappy.parquet
# part-00127-5d6701c4-b238-4c0a-84e4-fe8e9daea963-c000.snappy.parquet
# part-00084-5d6701c4-b238-4c0a-84e4-fe8e9daea963-c000.snappy.parquet

# %%
data = pd.read_parquet(tempDataset, engine='pyarrow')

# %%
import numpy
dfn= data.to_numpy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_24705/1541990558.py in <module>
#       1 import numpy
# ----> 2 dfn= data.to_numpy()
#
# NameError: name 'data' is not defined

# %%
import urllib
import requests

import certifi
import ssl
import gc

# %%
user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'
headers={'User-Agent':user_agent,} 
context = ssl._create_unverified_context()

# %%
wordSearch1= " nurse "
#wordSearch2="-nurse-"
rows = dfn.shape[0]
cols = dfn.shape[1]
#print( rows )
#print (cols)

download_folder = "/home/manish/Documents/folder_evaluate"
index = 0
count = 0


for x in range(0, rows-1):
    #gc.collect()
    val = dfn[x][1].find(wordSearch)
    #if val == -1 :
        #val = dfn[x][1].find(wordSearch2)
    #print("value of val: "+ str(val))
    if count == 10000:
        count = 0
        print("value of index :" + str(index))
    
    if val != -1:
        url = dfn[x][0]
        try:
            request=urllib.request.Request(url,None,headers) #The assembled request
            #resource = urllib.request.urlopen(request,context=ssl.create_default_context(cafile=certifi.where()))
            resource = urllib.request.urlopen(request,context=context)
            #print(resource)
        #print(resource)
            download_image_link= download_folder + "/" + "image"+ str(index) +".jpg"
            #print(url)
            output = open(download_image_link,"wb")
            output.write(resource.read())
            output.close()
            print(str(index)+ "  : "+dfn[x][1] + "     ")
            print("_++++++++++++++++++++++++++++++++++++++++++++++++++++_")
            print( "  : "+url + "     ")
            print("_-----------------------------------_")
            index = index+1
        except:
            continue 
    #count = count + 1
    #print(x)
# Out:
# 0  : Image result for richard prince nurse painting
# _++++++++++++++++++++++++++++++++++++++++++++++++++++_
#   : https://i.pinimg.com/originals/fe/d0/ee/fed0eedcf303b8c14b2958225eb8f8e7.jpg
# _-----------------------------------_
# 1  : Mildred Manning, then Mildred Dalton, was serving as a U.S. Army nurse in the Philippines when she was taken prisoner by Japanese forces in 1942.
# _++++++++++++++++++++++++++++++++++++++++++++++++++++_
#   : https://wfdd-live.s3.amazonaws.com/styles/slideshow/s3/images/slideshow/Army-Nurse-Mildred-Manning-An-Angel-POW-With-A-Job-To-Do-181994565-1445753437.jpg?itok=US81GPVH
# _-----------------------------------_
# 2  : critical care registered nurse resume sample
# _++++++++++++++++++++++++++++++++++++++++++++++++++++_
#   : https://lh4.googleusercontent.com/proxy/Tr0e0YxuQAIPiLzkKU2kzsIrruwFIJavnUdvdhhtwgqJlwPUTq8NQccgAGRQLvILLPIhaSmyWPc3SkDYXeT3wuKJzTv_N1OIvnlM1vpZSshuYl424tgyACo7AoPJvaqsV1SvXdu4O50ckchwIYLss_U2QZwhqyDC5aSRkORYJdLMrTU=s0-d
# ...

# %%
wordSearch=[" ceo "," CEO ","-ceo-","-CEO-","CHIEF EXECUTIVE OFFICER","chief executive officer"]
index = 0
download_folder = "/home/manish/Documents/ceos"

for dataset in os.listdir(folder_dir):
    datasetName = folder_dir+"/"+dataset
    data = pd.read_parquet(datasetName, engine='pyarrow')
    
    dfn= data.to_numpy()
    rows = dfn.shape[0]
    cols = dfn.shape[1]
    val = -1 
    for x in range(0, rows-1):
        
        for s in wordSearch:
            val=dfn[x][1].find(s)
            if val != -1 :
                break
            
        if val != -1:
            url = dfn[x][0]
            try:
                request=urllib.request.Request(url,None,headers) #The assembled request
                #resource = urllib.request.urlopen(request,context=ssl.create_default_context(cafile=certifi.where()))
                resource = urllib.request.urlopen(request,context=context)
                #print(resource)
            #print(resource)
                download_image_link= download_folder + "/" + "image"+ str(index) +".jpg"
                #print(url)
                output = open(download_image_link,"wb")
                output.write(resource.read())
                output.close()
                #print(str(index)+ "  : "+dfn[x][1] + "     ")
                #print("_++++++++++++++++++++++++++++++++++++++++++++++++++++_")
                #print( "  : "+url + "     ")
                #print("_-----------------------------------_")
                index = index+1
            except:
                continue 
    print("One dataset finished")
# Out:
# One dataset finished
# One dataset finished
# One dataset finished
# One dataset finished
